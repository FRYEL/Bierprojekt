# %%
import pandas as pd
from sklearn.model_selection import train_test_split


df = pd.read_csv("../data/base_data/CTGAN_basedata.csv")

# %%
# 80/20 Split
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# Optional: Speichern der Splits
train_df.to_csv("../data/real_train_data.csv", index=False)
test_df.to_csv("../data/real_test_data.csv", index=False)
