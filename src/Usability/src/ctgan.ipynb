# %%
import pandas as pd
from sdv.single_table import CTGANSynthesizer
from sdv.metadata import SingleTableMetadata
from sdv.evaluation.single_table import evaluate_quality
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Step 1: Load the dataset
# Assuming your data is in a CSV file named 'dataset.csv'
data = pd.read_csv('../data/base_data/CTGAN_basedata.csv')

# Handle missing values or "keine Angabe"
categorical_columns = ['geschlecht', 'bundesland', 'beruf', 'konsumhaeufigkeit']
for col in categorical_columns:
    data[col] = data[col].replace('keine Angabe', np.nan)  # Treat as NaN or keep as category

# Convert 'alter' to numeric, handling "keine Angabe"
data['alter'] = pd.to_numeric(data['alter'], errors='coerce')

# Step 2: Create metadata
metadata = SingleTableMetadata()
metadata.detect_from_dataframe(data)

# Explicitly set column types
for col in categorical_columns:
    metadata.update_column(column_name=col, sdtype='categorical')
metadata.update_column(column_name='alter', sdtype='numerical')  # Remove subtype

# Set ordinal columns (Likert-scale, 1–5) as numerical
ordinal_columns = [col for col in data.columns if col not in categorical_columns + ['alter']]
for col in ordinal_columns:
    metadata.update_column(column_name=col, sdtype='numerical')  # Remove subtype

# Validate metadata
metadata.validate()

# Step 3: Initialize and train the CTGAN model
synthesizer = CTGANSynthesizer(
    metadata=metadata,
    epochs=300,  # Adjust based on dataset complexity
    batch_size=100,
    verbose=True
)

# Fit the model
synthesizer.fit(data)

# Step 4: Generate synthetic data
synthetic_data = synthesizer.sample(num_rows=len(data))  # Generate 536 rows

# Step 5: Post-process synthetic data
# Round and clip ordinal columns to 1–5 and cast to integer
synthetic_data[ordinal_columns] = synthetic_data[ordinal_columns].round().clip(1, 5).astype('Int64')

# Round and clip 'alter' to a realistic range (e.g., 1900–2025 for year of birth)
synthetic_data['alter'] = synthetic_data['alter'].round().clip(1900, 2025).astype('Int64')

# Replace NaN in categorical columns with 'keine Angabe' if desired
for col in categorical_columns:
    synthetic_data[col] = synthetic_data[col].fillna('keine Angabe')

# Step 6: Save synthetic data
synthetic_data.to_csv('synthetic_data.csv', index=False)

# Step 7: Evaluate synthetic data quality
quality_report = evaluate_quality(
    real_data=data,
    synthetic_data=synthetic_data,
    metadata=metadata
)
print(f"Quality Report Score: {quality_report.get_score()}")
print("\nColumn Shapes Details:")
print(quality_report.get_details(property_name='Column Shapes'))
print("\nColumn Pair Trends Details:")
print(quality_report.get_details(property_name='Column Pair Trends'))

# Step 8: Visualize distributions
# Categorical column example
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.countplot(x='geschlecht', data=data)
plt.title('Original geschlecht Distribution')
plt.subplot(1, 2, 2)
sns.countplot(x='geschlecht', data=synthetic_data)
plt.title('Synthetic geschlecht Distribution')
plt.tight_layout()
plt.show()

# Ordinal column example
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.histplot(data['involvement_interesse'], bins=5)
plt.title('Original involvement_interesse Distribution')
plt.subplot(1, 2, 2)
sns.histplot(synthetic_data['involvement_interesse'], bins=5)
plt.title('Synthetic involvement_interesse Distribution')
plt.tight_layout()
plt.show()
# Out:
# /Users/yelf/PycharmProjects/Bierprojekt/.venv/lib/python3.12/site-packages/sdv/single_table/base.py:163: FutureWarning: The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#   warnings.warn(DEPRECATION_MSG, FutureWarning)
# /Users/yelf/PycharmProjects/Bierprojekt/.venv/lib/python3.12/site-packages/sdv/single_table/base.py:129: UserWarning: We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#   warnings.warn(
# Gen. (-6.93) | Discrim. (-1.75): 100%|██████████| 300/300 [01:16<00:00,  3.94it/s]
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 60/60 [00:00<00:00, 1855.11it/s]|
# Column Shapes Score: 85.95%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1770/1770 [00:02<00:00, 864.00it/s]|
# Column Pair Trends Score: 90.31%
#
# Overall Score (Average): 88.13%
#
# Quality Report Score: 0.8812754652004742
#
# Column Shapes Details:
#                                     Column        Metric     Score
# 0                               geschlecht  TVComplement  0.917910
# 1                                    alter  KSComplement  0.674743
# 2                               bundesland  TVComplement  0.724221
# 3                                    beruf  TVComplement  0.800743
# 4                        konsumhaeufigkeit  TVComplement  0.916045
# 5                situation_freunde_familie  KSComplement  0.753731
# 6                          situation_party  KSComplement  0.822761
# 7                  situation_zuhause_essen  KSComplement  0.927239
# 8            situation_zuhause_entspannung  KSComplement  0.791045
# 9   situation_oeffentliche_veranstaltungen  KSComplement  0.757463
# 10                        situation_gastro  KSComplement  0.884328
# 11                        situation_urlaub  KSComplement  0.811567
# 12                   involvement_interesse  KSComplement  0.929104
# 13                       involvement_rolle  KSComplement  0.901119
# 14                       involvement_spass  KSComplement  0.891791
# 15                 involvement_wichtigkeit  KSComplement  0.927239
# 16                 involvement_vorteilhaft  KSComplement  0.880597
# 17               involvement_unverzichtbar  KSComplement  0.854478
# 18                      gesundheit_wichtig  KSComplement  0.910448
# 19                umweltfreundlich_wichtig  KSComplement  0.761194
# 20                    neue_produkte_probie  KSComplement  0.929104
# 21                    bio_mehrpreis_bereit  KSComplement  0.867537
# 22                        tierfrei_wichtig  KSComplement  0.889925
# 23                 alkoholverzicht_wichtig  KSComplement  0.886194
# 24                      einfluss_geschmack  KSComplement  0.841418
# 25                         einfluss_geruch  KSComplement  0.873134
# 26                          einfluss_preis  KSComplement  0.843284
# 27              einfluss_markenbekanntheit  KSComplement  0.800373
# 28                 einfluss_nachhaltigkeit  KSComplement  0.882463
# 29                       einfluss_herkunft  KSComplement  0.912313
# 30              einfluss_verpackungsdesign  KSComplement  0.865672
# 31                einfluss_verpackungsform  KSComplement  0.822761
# 32                einfluss_aktionsangebote  KSComplement  0.735075
# 33                  einfluss_alkoholgehalt  KSComplement  0.858209
# 34                     einfluss_empfehlung  KSComplement  0.828358
# 35                 einfluss_verfuegbarkeit  KSComplement  0.891791
# 36                 praef_sorte_alkoholfrei  KSComplement  0.884328
# 37                      praef_sorte_weizen  KSComplement  0.860075
# 38                     praef_sorte_koelsch  KSComplement  0.919776
# 39                     praef_sorte_altbier  KSComplement  0.723881
# 40                    praef_sorte_pale_ale  KSComplement  0.869403
# 41                       praef_sorte_stout  KSComplement  0.904851
# 42              praef_sorte_maerzen_export  KSComplement  0.750000
# 43                      praef_sorte_radler  KSComplement  0.925373
# 44                        praef_sorte_pils  KSComplement  0.917910
# 45       praef_sorte_bock_schwarzrauchbier  KSComplement  0.955224
# 46                praef_sorte_helles_lager  KSComplement  0.949627
# 47                  praef_sorte_craft_beer  KSComplement  0.884328
# 48                     praef_alkoholfrei_0  KSComplement  0.873134
# 49                   praef_alkoholfrei_0_5  KSComplement  0.921642
# 50                      praef_bier_alkohol  KSComplement  0.796642
# 51                       geschmack_rauchig  KSComplement  0.945896
# 52                        geschmack_hopfig  KSComplement  0.910448
# 53              geschmack_suesslich_malzig  KSComplement  0.867537
# 54                      geschmack_fruchtig  KSComplement  0.811567
# 55                      geschmack_kraeuter  KSComplement  0.932836
# 56                      geschmack_gewuerze  KSComplement  0.854478
# 57                        geschmack_bitter  KSComplement  0.899254
# 58                    geschmack_saeuerlich  KSComplement  0.860075
# 59                        geschmack_zitrus  KSComplement  0.783582
#
# Column Pair Trends Details:
#                   Column 1                   Column 2                 Metric  \
# 0               geschlecht                      alter  ContingencySimilarity
# 1               geschlecht                 bundesland  ContingencySimilarity
# 2               geschlecht                      beruf  ContingencySimilarity
# 3               geschlecht          konsumhaeufigkeit  ContingencySimilarity
# 4               geschlecht  situation_freunde_familie  ContingencySimilarity
# ...                    ...                        ...                    ...
# 1765    geschmack_gewuerze       geschmack_saeuerlich  CorrelationSimilarity
# 1766    geschmack_gewuerze           geschmack_zitrus  CorrelationSimilarity
# 1767      geschmack_bitter       geschmack_saeuerlich  CorrelationSimilarity
# 1768      geschmack_bitter           geschmack_zitrus  CorrelationSimilarity
# 1769  geschmack_saeuerlich           geschmack_zitrus  CorrelationSimilarity
#
#          Score  Real Correlation  Synthetic Correlation
# 0     0.567164               NaN                    NaN
# 1     0.602612               NaN                    NaN
# 2     0.662313               NaN                    NaN
# 3     0.835821               NaN                    NaN
# 4     0.753731               NaN                    NaN
# ...        ...               ...                    ...
# 1765  0.923615          0.211476               0.058706
# 1766  0.947632          0.072189              -0.032547
# 1767  0.866163          0.267821               0.000147
# 1768  0.907314         -0.188163              -0.002790
# 1769  0.952538          0.126434               0.031510
#
# [1770 rows x 6 columns]

# %%
import pandas as pd
from sdv.single_table import CTGANSynthesizer
from sdv.metadata import SingleTableMetadata
from sdv.evaluation.single_table import evaluate_quality
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Step 1: Load the dataset
# Assuming your data is in a CSV file named 'dataset.csv'
data = pd.read_csv('../data/base_data/CTGAN_basedata.csv')

# Handle 'keine Angabe' for categorical columns with mode
categorical_columns = ['geschlecht', 'bundesland', 'beruf', 'konsumhaeufigkeit']
for col in categorical_columns:
    mode_value = data[col][data[col] != 'keine Angabe'].mode()[0]  # Get mode excluding 'keine Angabe'
    data[col] = data[col].replace('keine Angabe', mode_value)

# Convert 'alter' to numeric and impute 'keine Angabe' with median
data['alter'] = pd.to_numeric(data['alter'], errors='coerce')  # Convert to numeric, 'keine Angabe' becomes NaN
median_alter = data['alter'].median()  # Compute median of valid values
data['alter'] = data['alter'].fillna(median_alter)  # Impute NaN with median

# Step 2: Create metadata
metadata = SingleTableMetadata()
metadata.detect_from_dataframe(data)

# Explicitly set column types
for col in categorical_columns:
    metadata.update_column(column_name=col, sdtype='categorical')
metadata.update_column(column_name='alter', sdtype='numerical')

# Set ordinal columns (Likert-scale, 1–5) as numerical
ordinal_columns = [col for col in data.columns if col not in categorical_columns + ['alter']]
for col in ordinal_columns:
    metadata.update_column(column_name=col, sdtype='numerical')

# Validate metadata
metadata.validate()

# Step 3: Initialize and train the CTGAN model
synthesizer = CTGANSynthesizer(
    metadata=metadata,
    epochs=300,  # Adjust based on dataset complexity
    batch_size=100,
    verbose=True
)

# Fit the model
synthesizer.fit(data)

# Step 4: Generate synthetic data
synthetic_data = synthesizer.sample(num_rows=len(data))  # Generate 536 rows

# Step 5: Post-process synthetic data
# Round and clip ordinal columns to 1–5 and cast to integer
synthetic_data[ordinal_columns] = synthetic_data[ordinal_columns].round().clip(1, 5).astype('Int64')

# Round and clip 'alter' to a realistic range (e.g., 1900–2025 for year of birth)
synthetic_data['alter'] = synthetic_data['alter'].round().clip(1900, 2025).astype('Int64')

# Step 6: Save synthetic data
synthetic_data.to_csv('synthetic_data.csv', index=False)

# Step 7: Evaluate synthetic data quality
quality_report = evaluate_quality(
    real_data=data,
    synthetic_data=synthetic_data,
    metadata=metadata
)
print(f"Quality Report Score: {quality_report.get_score()}")
print("\nColumn Shapes Details:")
print(quality_report.get_details(property_name='Column Shapes'))
print("\nColumn Pair Trends Details:")
print(quality_report.get_details(property_name='Column Pair Trends'))

# Step 8: Visualize distributions
# Categorical column example
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.countplot(x='geschlecht', data=data)
plt.title('Original geschlecht Distribution')
plt.subplot(1, 2, 2)
sns.countplot(x='geschlecht', data=synthetic_data)
plt.title('Synthetic geschlecht Distribution')
plt.tight_layout()
plt.show()

# Ordinal column example
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.histplot(data['involvement_interesse'], bins=5)
plt.title('Original involvement_interesse Distribution')
plt.subplot(1, 2, 2)
sns.histplot(synthetic_data['involvement_interesse'], bins=5)
plt.title('Synthetic involvement_interesse Distribution')
plt.tight_layout()
plt.show()
# Out:
# /Users/yelf/PycharmProjects/Bierprojekt/.venv/lib/python3.12/site-packages/sdv/single_table/base.py:163: FutureWarning: The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#   warnings.warn(DEPRECATION_MSG, FutureWarning)
# /Users/yelf/PycharmProjects/Bierprojekt/.venv/lib/python3.12/site-packages/sdv/single_table/base.py:129: UserWarning: We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#   warnings.warn(
# Gen. (-7.34) | Discrim. (-0.39): 100%|██████████| 300/300 [01:15<00:00,  3.96it/s]
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 60/60 [00:00<00:00, 2118.94it/s]|
# Column Shapes Score: 86.28%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1770/1770 [00:01<00:00, 919.78it/s]|
# Column Pair Trends Score: 91.06%
#
# Overall Score (Average): 88.67%
#
# Quality Report Score: 0.8867282210614436
#
# Column Shapes Details:
#                                     Column        Metric     Score
# 0                               geschlecht  TVComplement  0.944030
# 1                                    alter  KSComplement  0.679104
# 2                               bundesland  TVComplement  0.882463
# 3                                    beruf  TVComplement  0.889925
# 4                        konsumhaeufigkeit  TVComplement  0.917910
# 5                situation_freunde_familie  KSComplement  0.854478
# 6                          situation_party  KSComplement  0.861940
# 7                  situation_zuhause_essen  KSComplement  0.861940
# 8            situation_zuhause_entspannung  KSComplement  0.906716
# 9   situation_oeffentliche_veranstaltungen  KSComplement  0.958955
# 10                        situation_gastro  KSComplement  0.936567
# 11                        situation_urlaub  KSComplement  0.744403
# 12                   involvement_interesse  KSComplement  0.805970
# 13                       involvement_rolle  KSComplement  0.953358
# 14                       involvement_spass  KSComplement  0.850746
# 15                 involvement_wichtigkeit  KSComplement  0.826493
# 16                 involvement_vorteilhaft  KSComplement  0.893657
# 17               involvement_unverzichtbar  KSComplement  0.815299
# 18                      gesundheit_wichtig  KSComplement  0.889925
# 19                umweltfreundlich_wichtig  KSComplement  0.819030
# 20                    neue_produkte_probie  KSComplement  0.809701
# 21                    bio_mehrpreis_bereit  KSComplement  0.957090
# 22                        tierfrei_wichtig  KSComplement  0.772388
# 23                 alkoholverzicht_wichtig  KSComplement  0.861940
# 24                      einfluss_geschmack  KSComplement  0.841418
# 25                         einfluss_geruch  KSComplement  0.835821
# 26                          einfluss_preis  KSComplement  0.873134
# 27              einfluss_markenbekanntheit  KSComplement  0.917910
# 28                 einfluss_nachhaltigkeit  KSComplement  0.919776
# 29                       einfluss_herkunft  KSComplement  0.972015
# 30              einfluss_verpackungsdesign  KSComplement  0.811567
# 31                einfluss_verpackungsform  KSComplement  0.843284
# 32                einfluss_aktionsangebote  KSComplement  0.830224
# 33                  einfluss_alkoholgehalt  KSComplement  0.938433
# 34                     einfluss_empfehlung  KSComplement  0.886194
# 35                 einfluss_verfuegbarkeit  KSComplement  0.871269
# 36                 praef_sorte_alkoholfrei  KSComplement  0.837687
# 37                      praef_sorte_weizen  KSComplement  0.960821
# 38                     praef_sorte_koelsch  KSComplement  0.692164
# 39                     praef_sorte_altbier  KSComplement  0.817164
# 40                    praef_sorte_pale_ale  KSComplement  0.951493
# 41                       praef_sorte_stout  KSComplement  0.785448
# 42              praef_sorte_maerzen_export  KSComplement  0.833955
# 43                      praef_sorte_radler  KSComplement  0.843284
# 44                        praef_sorte_pils  KSComplement  0.871269
# 45       praef_sorte_bock_schwarzrauchbier  KSComplement  0.895522
# 46                praef_sorte_helles_lager  KSComplement  0.925373
# 47                  praef_sorte_craft_beer  KSComplement  0.638060
# 48                     praef_alkoholfrei_0  KSComplement  0.815299
# 49                   praef_alkoholfrei_0_5  KSComplement  0.815299
# 50                      praef_bier_alkohol  KSComplement  0.871269
# 51                       geschmack_rauchig  KSComplement  0.914179
# 52                        geschmack_hopfig  KSComplement  0.912313
# 53              geschmack_suesslich_malzig  KSComplement  0.847015
# 54                      geschmack_fruchtig  KSComplement  0.875000
# 55                      geschmack_kraeuter  KSComplement  0.945896
# 56                      geschmack_gewuerze  KSComplement  0.942164
# 57                        geschmack_bitter  KSComplement  0.889925
# 58                    geschmack_saeuerlich  KSComplement  0.826493
# 59                        geschmack_zitrus  KSComplement  0.828358
#
# Column Pair Trends Details:
#                   Column 1                   Column 2                 Metric  \
# 0               geschlecht                      alter  ContingencySimilarity
# 1               geschlecht                 bundesland  ContingencySimilarity
# 2               geschlecht                      beruf  ContingencySimilarity
# 3               geschlecht          konsumhaeufigkeit  ContingencySimilarity
# 4               geschlecht  situation_freunde_familie  ContingencySimilarity
# ...                    ...                        ...                    ...
# 1765    geschmack_gewuerze       geschmack_saeuerlich  CorrelationSimilarity
# 1766    geschmack_gewuerze           geschmack_zitrus  CorrelationSimilarity
# 1767      geschmack_bitter       geschmack_saeuerlich  CorrelationSimilarity
# 1768      geschmack_bitter           geschmack_zitrus  CorrelationSimilarity
# 1769  geschmack_saeuerlich           geschmack_zitrus  CorrelationSimilarity
#
#          Score  Real Correlation  Synthetic Correlation
# 0     0.626866               NaN                    NaN
# 1     0.863806               NaN                    NaN
# 2     0.820896               NaN                    NaN
# 3     0.830224               NaN                    NaN
# 4     0.807836               NaN                    NaN
# ...        ...               ...                    ...
# 1765  0.866612          0.211476              -0.055300
# 1766  0.961652          0.072189              -0.004506
# 1767  0.870394          0.267821               0.008608
# 1768  0.911756         -0.188163              -0.011675
# 1769  0.964292          0.126434               0.055019
#
# [1770 rows x 6 columns]
