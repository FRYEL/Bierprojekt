# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('synthetic_dataset_schema.csv')

# %%
df.head(10)
# Out:
#    geschlecht  alter  bundesland  beruf  konsumhaeufigkeit  \
# 0           2      6           1      3                  5
# 1           1      6           1      3                  3
# 2           2      8           2      1                  3
# 3         -99    -99         -99    -99                  2
# 4           1      5           1      3                  3
# 5           1    -99         -99    -99                  2
# 6         -99    -99         -99    -99                  3
# 7           1      5           1      3                  2
# 8           1      8           1      3                  3
# 9           1     11           1      3                  2
#
#    situation_freunde_familie  situation_party  situation_zuhause_essen  \
# 0                          2                2                        1
# 1                          2                2                        1
# 2                          3                3                        2
# ...

# %%
df.describe()
# Out:
#        geschlecht       alter  bundesland       beruf  konsumhaeufigkeit  \
# count  536.000000  536.000000  536.000000  536.000000         536.000000
# mean    -8.035448   -2.365672   -8.333955   -7.283582           3.072761
# std     29.207678   32.815267   30.142751   30.126987           1.019586
# min    -99.000000  -99.000000  -99.000000  -99.000000           1.000000
# 25%      1.000000    6.000000    1.000000    1.000000           2.000000
# 50%      1.000000    8.000000    1.000000    3.000000           3.000000
# 75%      2.000000   10.000000    1.000000    3.000000           4.000000
# max      3.000000   15.000000   17.000000    9.000000           5.000000
#
#        situation_freunde_familie  situation_party  situation_zuhause_essen  \
# count                 536.000000       536.000000               536.000000
# mean                    2.248134         2.085821                 0.445896
# std                     4.417890         7.608659                 9.674944
# ...

# %%
df.corr()
# Out:
#                                         geschlecht     alter  bundesland  \
# geschlecht                                1.000000  0.838021    0.880651
# alter                                     0.838021  1.000000    0.848430
# bundesland                                0.880651  0.848430    1.000000
# beruf                                     0.868470  0.837858    0.877966
# konsumhaeufigkeit                         0.040194  0.053366    0.068605
# situation_freunde_familie                -0.009536  0.129583    0.134893
# situation_party                          -0.018583  0.055307    0.145610
# situation_zuhause_essen                  -0.033361  0.090615    0.033097
# situation_zuhause_entspannung            -0.038308  0.071854    0.018959
# situation_oeffentliche_veranstaltungen    0.004656  0.046722    0.043078
# situation_gastro                          0.049245  0.071907    0.080168
# situation_urlaub                         -0.025955  0.032665    0.000225
# ...

# %%
corr = df.corr()

# 3) Erstelle den Plot
fig, ax = plt.subplots()
cax = ax.matshow(corr)                     # Heatmap
fig.colorbar(cax)                          # Farblegende
ticks = range(len(corr.columns))
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(corr.columns, rotation=90)
ax.set_yticklabels(corr.columns)
plt.title("Korrelationsmatrix")
#plt.tight_layout()
plt.show()

# %%
# 2) Korrelationsmatrix berechnen
corr = df.corr()

# 3) Oberes Dreieck maskieren
mask = np.triu(np.ones_like(corr, dtype=bool))

# 4) Plot erstellen
fig, ax = plt.subplots(figsize=(16, 16))
cax = ax.matshow(corr, cmap='plasma', vmin=-1, vmax=1)
fig.colorbar(cax, fraction=0.046, pad=0.04)

# 5) Achseneinstellungen
ticks = np.arange(len(corr.columns))
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(corr.columns, rotation=90, fontsize=8)
ax.set_yticklabels(corr.columns, fontsize=8)

# 6) Maske überzeichnen
for i in range(len(corr.columns)):
    for j in range(len(corr.columns)):
        if mask[i, j]:
            ax.add_patch(plt.Rectangle((j-0.5, i-0.5), 1, 1, color='white'))

plt.title("Korrelationsmatrix – Übersicht", pad=20, fontsize=14)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 1) Daten laden
df = pd.read_csv('synthetic_dataset_schema.csv')  # Pfad ggf. anpassen

# 2) Spalten definieren
taste_cols = [col for col in df.columns if col.startswith('geschmack_')]
other_cols = [col for col in df.columns if col not in taste_cols]

# 3) Korrelationsmatrix berechnen
corr = df.corr()

# 4) Submatrix: Nur andere Merkmale vs. Geschmackspräferenzen
sub_corr = corr.loc[other_cols, taste_cols]

# 5) Plot – Heatmap
plt.figure(figsize=(14, 10))
sns.heatmap(
    sub_corr,
    cmap='coolwarm',  # Alternative: 'vlag', 'RdBu', 'viridis'
    center=0,
    annot=True,
    fmt=".2f",
    linewidths=0.5,
    cbar_kws={"label": "Korrelationskoeffizient"}
)
plt.title("Korrelationen zwischen Merkmalen und Geschmackspräferenzen", fontsize=14, pad=15)
plt.xlabel("Geschmackspräferenzen")
plt.ylabel("Merkmale")
plt.tight_layout()
plt.show()
