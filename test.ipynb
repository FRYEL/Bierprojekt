# %%
import pandas as pd

# %%
df = pd.read_csv('Daten/synthetic_dataset_schema.csv')

# %%
df.head(10)
# Out:
#    geschlecht  alter  bundesland  beruf  konsumhaeufigkeit  \
# 0           2      6           1      3                  5
# 1           1      6           1      3                  3
# 2           2      8           2      1                  3
# 3         -99    -99         -99    -99                  2
# 4           1      5           1      3                  3
# 5           1    -99         -99    -99                  2
# 6         -99    -99         -99    -99                  3
# 7           1      5           1      3                  2
# 8           1      8           1      3                  3
# 9           1     11           1      3                  2
#
#    situation_freunde_familie  situation_party  situation_zuhause_essen  \
# 0                          2                2                        1
# 1                          2                2                        1
# 2                          3                3                        2
# ...
